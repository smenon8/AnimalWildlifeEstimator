# %% [raw]
# Processing data from .results files

# %%
masterList = {}

for i in range(5,6):    
    inFL = "../results/photo_album_" + str(i) + ".results"
    inFLList = []
    with open(inFL,"r") as inp:
        for line in inp:
            inFLList.append(line)

    resultList = []
    header = inFLList[0].split("\t")
    for line in inFLList[1:]:
        resultList.append(line.split("\t"))

    resultDict = {}
    for i in range(0,len(resultList)):
        for j in range(0,len(header)):
            resultDict[header[j]] = resultDict.get(header[j],[]) + [resultList[i][j]]

    keysOfInterest = list(filter(lambda x: re.search("Answer",x),resultDict.keys()))
    newDict = {}
    for key in keysOfInterest:
        newDict[key] = resultDict[key]

    masterList[inFL] = newDict

# %%
masterList['../results/photo_album_5.results']
# Out:
# {'"Answer.6430"': ['"6430|share"',
#   '"351|share"',
#   '"351|share"',
#   '"351|share"',
#   '"351|share"',
#   '"351|share"',
#   '"351|share"'],
#  '"Answer.6431"': ['"6431|share"',
#   '"350|share"',
#   '"350|share"',
#   '"350|share"',
#   '"350|share"',
#   '"350|share"',
#   '"350|share"'],
#  '"Answer.6471"': ['"6471|share"',
#   '"406|share"',
#   '"406|share"',
#   '"406|share"',
#   '"406|share"',
#   '"406|share"',
#   '"406|share"'],
#  '"Answer.6475"': ['"6475|share"',
#   '"394|share"',
#   '"394|share"',
#   '"394|share"',
#   '"394|share"',
#   '"394|share"',
#   '"394|share"'],
#  '"Answer.6536"': ['"6536|share"',
#   '"385|share"',
#   '"385|share"',
#   '"385|share"',
#   '"385|share"',
#   '"385|share"',
#   '"385|share"'],
#  '"Answer.6539"': ['"6539|share"',
#   '"374|share"',
#   '"374|share"',
#   '"374|share"',
#   '"374|share"',
#   '"374|share"',
#   '"374|share"'],
#  '"Answer.6560"': ['"6560|share"',
#   '"352|share"',
#   '"352|share"',
#   '"352|share"',
#   '"352|share"',
#   '"352|share"',
#   '"352|share"'],
#  '"Answer.6585"': ['"6585|share"',
#   '"395|share"',
#   '"395|share"',
#   '"395|share"',
#   '"395|share"',
#   '"395|share"',
#   '"395|share"'],
#  '"Answer.6586"': ['"6586|share"',
#   '"399|share"',
#   '"399|share"',
#   '"399|share"',
#   '"399|share"',
#   '"399|share"',
#   '"399|share"'],
#  '"Answer.6587"': ['"6587|share"',
#   '"370|share"',
#   '"370|share"',
#   '"370|share"',
#   '"370|share"',
#   '"370|share"',
#   '"370|share"'],
#  '"Answer.6590"': ['"6590|share"',
#   '"354|share"',
#   '"354|share"',
#   '"354|share"',
#   '"354|share"',
#   '"354|share"',
#   '"354|share"'],
#  '"Answer.6597"': ['"6597|noShare"',
#   '"359|noShare"',
#   '"359|noShare"',
#   '"359|noShare"',
#   '"359|noShare"',
#   '"359|noShare"',
#   '"359|noShare"'],
#  '"Answer.6643"': ['"6643|share"',
#   '"388|share"',
#   '"388|share"',
#   '"388|share"',
#   '"388|share"',
#   '"388|share"',
#   '"388|share"'],
#  '"Answer.6653"': ['"6653|noShare"',
#   '"360|share"',
#   '"360|share"',
#   '"360|share"',
#   '"360|share"',
#   '"360|share"',
#   '"360|share"'],
#  '"Answer.6686"': ['"6686|share"',
#   '"403|share"',
#   '"403|share"',
#   '"403|share"',
#   '"403|share"',
#   '"403|share"',
#   '"403|share"'],
#  '"Answer.6698"': ['"6698|share"',
#   '"377|share"',
#   '"377|share"',
#   '"377|share"',
#   '"377|share"',
#   '"377|share"',
#   '"377|share"'],
#  '"Answer.6731"': ['"6731|share"',
#   '"373|share"',
#   '"373|share"',
#   '"373|share"',
#   '"373|share"',
#   '"373|share"',
#   '"373|share"'],
#  '"Answer.6734"': ['"6734|share"',
#   '"362|share"',
#   '"362|share"',
#   '"362|share"',
#   '"362|share"',
#   '"362|share"',
#   '"362|share"'],
#  '"Answer.6759"': ['"6759|share"',
#   '"353|share"',
#   '"353|share"',
#   '"353|share"',
#   '"353|share"',
#   '"353|share"',
#   '"353|share"'],
#  '"Answer.6811"': ['"6811|noShare"',
#   '"369|share"',
#   '"369|share"',
#   '"369|share"',
#   '"369|share"',
#   '"369|share"',
#   '"369|share"'],
#  '"Answer.generalComments"': ['"nice pictures"',
#   '""',
#   '""',
#   '""',
#   '""',
#   '""',
#   '""'],
#  '"Answer.q1"': ['"infrequently"',
#   '"everyday"',
#   '"everyday"',
#   '"everyday"',
#   '"everyday"',
#   '"everyday"',
#   '"everyday"'],
#  '"Answer.q2"': ['"E"', '"C"', '"C"', '"C"', '"C"', '"C"', '"C"'],
#  '"Answer.submitButton"\n': ['"Submit"\n',
#   '"Submit"\n',
#   '"Submit"\n',
#   '"Submit"\n',
#   '"Submit"\n',
#   '"Submit"\n',
#   '"Submit"\n']}

# %%
import re

# %%
resultDict
# Out:
# {'"Answer.6430"': '"351|share"',
#  '"Answer.6431"': '"350|share"',
#  '"Answer.6471"': '"406|share"',
#  '"Answer.6475"': '"394|share"',
#  '"Answer.6536"': '"385|share"',
#  '"Answer.6539"': '"374|share"',
#  '"Answer.6560"': '"352|share"',
#  '"Answer.6585"': '"395|share"',
#  '"Answer.6586"': '"399|share"',
#  '"Answer.6587"': '"370|share"',
#  '"Answer.6590"': '"354|share"',
#  '"Answer.6597"': '"359|noShare"',
#  '"Answer.6643"': '"388|share"',
#  '"Answer.6653"': '"360|share"',
#  '"Answer.6686"': '"403|share"',
#  '"Answer.6698"': '"377|share"',
#  '"Answer.6731"': '"373|share"',
#  '"Answer.6734"': '"362|share"',
#  '"Answer.6759"': '"353|share"',
#  '"Answer.6811"': '"369|share"',
#  '"Answer.generalComments"': '""',
#  '"Answer.q1"': '"everyday"',
#  '"Answer.q2"': '"C"',
#  '"Answer.submitButton"\n': '"Submit"\n',
#  '"annotation"': '"${image_url}"',
#  '"assignmentaccepttime"': '"Tue May 17 22:46:44 CDT 2016"',
#  '"assignmentapprovaltime"': '"Fri May 20 22:53:09 CDT 2016"',
#  '"assignmentduration"': '"3600"',
#  '"assignmentid"': '"3JV9LGBJWUAO310STH5TSVLCSCWGO9"',
#  '"assignmentrejecttime"': '""',
#  '"assignments"': '"1"',
#  '"assignmentstatus"': '"Approved"',
#  '"assignmentsubmittime"': '"Tue May 17 22:48:22 CDT 2016"',
#  '"autoapprovaldelay"': '"259200"',
#  '"autoapprovaltime"': '"Fri May 20 22:48:22 CDT 2016"',
#  '"creationtime"': '"Tue May 17 22:44:18 CDT 2016"',
#  '"deadline"': '""',
#  '"description"': '"You will be shown an image which you will need to categorize"',
#  '"feedback"': '""',
#  '"hitid"': '"302OLP89DZ3JX1STRAZRDPLAT2MACZ"',
#  '"hitlifetime"': '"Tue May 24 22:44:18 CDT 2016"',
#  '"hitstatus"': '"Reviewable"',
#  '"hittypeid"': '"3PS3UFWQYLZ8PCNXJ59IPMUURDFYRP"',
#  '"keywords"': '"category, categorize, image, pictures, photo"',
#  '"numavailable"': '"0"',
#  '"numcomplete"': '"1"',
#  '"numpending"': '"0"',
#  '"reject"': '""',
#  '"reviewstatus"': '"NotReviewed"',
#  '"reward"': '"$0.00"',
#  '"title"': '"Create a photo album"',
#  '"viewhit"': '"https://requester.mturk.com/mturk/manageHIT?HITId=302OLP89DZ3JX1STRAZRDPLAT2MACZ"',
#  '"workerid"': '"A34QVV6QUHYMST"'}
