# %%
import csv
import htmltag as HT
import DeriveFinalResultSet as drs
import JobsMapResultsFilesToContainerObjs as ImageMap
import pandas as pd
import matplotlib.pyplot as plt
import importlib
import statistics as s
importlib.reload(drs)
importlib.reload(ImageMap)
pd.set_option('display.max_colwidth', -1)

# %%
def genHTMLTableFiles(shrCntsObj):
    shrPropDict = drs.getShrProp(shrCntsObj)
    
    df = pd.DataFrame(shrPropDict,index = ['Share Proportion']).transpose()
    
    return df,df.to_html(bold_rows = False)

# %%
# Generate rank list of all images by share proportion
rnkFlLst = []
with open("../data/rankListImages_expt2.csv","r") as rnkFl:
    rnkFlCsv = csv.reader(rnkFl)
    header = rnkFlCsv.__next__()
    for row in rnkFlCsv:
        rnkFlLst.append(row)
        
thTgs = []
trTgs = []

trTgs.append(HT.tr(HT.th("GID"),HT.th("Share count"),HT.th("Not Share count"),
                  HT.th("Total Count"),HT.th("Share Proportion"),HT.th("Image")))

for tup in rnkFlLst:
    tdGid = HT.td(tup[0])
    tdShare = HT.td(tup[1])
    tdNotShare = HT.td(tup[2])
    tdTot = HT.td(tup[3])
    tdProp = HT.td(tup[4])
    url = "https://socialmediabias.blob.core.windows.net/wildlifephotos/All_Zebra_Count_Images/" + tup[0] + ".jpeg"
    tdImg = HT.td(HT.img(src = url,alt = "Unavailable",width = "300"))
    trTgs.append(HT.tr(tdGid,tdShare,tdNotShare,tdTot,tdProp,tdImg))
    
fullFile = HT.html(HT.body(HT.table(HT.HTML('  \n'.join(trTgs)),border="1")))

outputFile = open("../data/resultsExpt2RankList.html","w")
outputFile.write(fullFile)
outputFile.close()

# %%
d = drs.ovrallShrCntsByTwoFtrs(drs.gidAidMapFl,drs.aidFeatureMapFl,"SPECIES","AGE",drs.imgJobMap,1,100)
h3_1 = HT.h3("Data-Frame by SPECIES-AGE")
df1,tb1 = genHTMLTableFiles(d)

d = drs.ovrallShrCntsByTwoFtrs(drs.gidAidMapFl,drs.aidFeatureMapFl,"SPECIES","SEX",drs.imgJobMap,1,100)
h3_2 = HT.h3("Data-Frame by SPECIES-SEX")
df2,tb2 = genHTMLTableFiles(d)

d = drs.ovrallShrCntsByTwoFtrs(drs.gidAidMapFl,drs.aidFeatureMapFl,"SPECIES","VIEW_POINT",drs.imgJobMap,1,100)
h3_3 = HT.h3("Data-Frame by SPECIES-VIEW_POINT")
df3,tb3 = genHTMLTableFiles(d)

d = drs.ovrallShrCntsByTwoFtrs(drs.gidAidMapFl,drs.aidFeatureMapFl,"SPECIES","QUALITY",drs.imgJobMap,1,100)
h3_4 = HT.h3("Data-Frame by SPECIES-QUALITY")
df4,tb4 = genHTMLTableFiles(d)

d = drs.ovrallShrCntsByTwoFtrs(drs.gidAidMapFl,drs.aidFeatureMapFl,"SPECIES","EXEMPLAR_FLAG",drs.imgJobMap,1,100)
h3_5 = HT.h3("Data-Frame by SPECIES-EXEMPLAR_FLAG")
df5,tb5 = genHTMLTableFiles(d)

## *******## *******## *******## *******## *******## *******## *******## *******

d = drs.ovrallShrCntsByTwoFtrs(drs.gidAidMapFl,drs.aidFeatureMapFl,"VIEW_POINT","SPECIES",drs.imgJobMap,1,100)
h3_6 = HT.h3("Data-Frame by VIEW_POINT-SPECIES")
df6,tb6 = genHTMLTableFiles(d)

d = drs.ovrallShrCntsByTwoFtrs(drs.gidAidMapFl,drs.aidFeatureMapFl,"VIEW_POINT","AGE",drs.imgJobMap,1,100)
h3_7 = HT.h3("Data-Frame by VIEW_POINT-AGE")
df7,tb7 = genHTMLTableFiles(d)

d = drs.ovrallShrCntsByTwoFtrs(drs.gidAidMapFl,drs.aidFeatureMapFl,"VIEW_POINT","SEX",drs.imgJobMap,1,100)
h3_8 = HT.h3("Data-Frame by VIEW_POINT-SEX")
df8,tb8 = genHTMLTableFiles(d)

d = drs.ovrallShrCntsByTwoFtrs(drs.gidAidMapFl,drs.aidFeatureMapFl,"VIEW_POINT","QUALITY",drs.imgJobMap,1,100)
h3_9 = HT.h3("Data-Frame by VIEW_POINT-QUALITY")
df9,tb9 = genHTMLTableFiles(d)

d = drs.ovrallShrCntsByTwoFtrs(drs.gidAidMapFl,drs.aidFeatureMapFl,"VIEW_POINT","EXEMPLAR_FLAG",drs.imgJobMap,1,100)
h3_10 = HT.h3("Data-Frame by VIEW_POINT-EXEMPLAR_FLAG")
df10,tb10 = genHTMLTableFiles(d)

## *******## *******## *******## *******## *******## *******## *******## *******
d = drs.ovrallShrCntsByTwoFtrs(drs.gidAidMapFl,drs.aidFeatureMapFl,"SEX","SPECIES",drs.imgJobMap,1,100)
h3_11 = HT.h3("Data-Frame by SEX-SPECIES")
df11,tb11 = genHTMLTableFiles(d)

d = drs.ovrallShrCntsByTwoFtrs(drs.gidAidMapFl,drs.aidFeatureMapFl,"SEX","AGE",drs.imgJobMap,1,100)
h3_12 = HT.h3("Data-Frame by SEX-AGE")
df12,tb12 = genHTMLTableFiles(d)

d = drs.ovrallShrCntsByTwoFtrs(drs.gidAidMapFl,drs.aidFeatureMapFl,"SEX","QUALITY",drs.imgJobMap,1,100)
h3_13 = HT.h3("Data-Frame by SEX-QUALITY")
df13,tb13 = genHTMLTableFiles(d)

d = drs.ovrallShrCntsByTwoFtrs(drs.gidAidMapFl,drs.aidFeatureMapFl,"SEX","EXEMPLAR_FLAG",drs.imgJobMap,1,100)
h3_14 = HT.h3("Data-Frame by SEX-EXEMPLAR_FLAG")
df14,tb14 = genHTMLTableFiles(d)

d = drs.ovrallShrCntsByTwoFtrs(drs.gidAidMapFl,drs.aidFeatureMapFl,"SEX","VIEW_POINT",drs.imgJobMap,1,100)
h3_15 = HT.h3("Data-Frame by SEX-VIEW_POINT")
df15,tb15 = genHTMLTableFiles(d)

## *******## *******## *******## *******## *******## *******## *******## *******
d = drs.ovrallShrCntsByTwoFtrs(drs.gidAidMapFl,drs.aidFeatureMapFl,"AGE","SPECIES",drs.imgJobMap,1,100)
h3_16 = HT.h3("Data-Frame by AGE-SPECIES")
df16,tb16 = genHTMLTableFiles(d)

d = drs.ovrallShrCntsByTwoFtrs(drs.gidAidMapFl,drs.aidFeatureMapFl,"AGE","SEX",drs.imgJobMap,1,100)
h3_17 = HT.h3("Data-Frame by AGE-SEX")
df17,tb17 = genHTMLTableFiles(d)

d = drs.ovrallShrCntsByTwoFtrs(drs.gidAidMapFl,drs.aidFeatureMapFl,"AGE","QUALITY",drs.imgJobMap,1,100)
h3_18 = HT.h3("Data-Frame by AGE-QUALITY")
df18,tb18 = genHTMLTableFiles(d)

d = drs.ovrallShrCntsByTwoFtrs(drs.gidAidMapFl,drs.aidFeatureMapFl,"AGE","EXEMPLAR_FLAG",drs.imgJobMap,1,100)
h3_19 = HT.h3("Data-Frame by AGE-EXEMPLAR_FLAG")
df19,tb19 = genHTMLTableFiles(d)

d = drs.ovrallShrCntsByTwoFtrs(drs.gidAidMapFl,drs.aidFeatureMapFl,"AGE","VIEW_POINT",drs.imgJobMap,1,100)
h3_20 = HT.h3("Data-Frame by AGE-VIEW_POINT")
df20,tb20 = genHTMLTableFiles(d)



fullFl = HT.html(HT.body(HT.HTML(h3_1),HT.HTML(tb1),
                        HT.HTML(h3_2),HT.HTML(tb2),
                        HT.HTML(h3_3),HT.HTML(tb3),
                        HT.HTML(h3_4),HT.HTML(tb4),
                        HT.HTML(h3_5),HT.HTML(tb5),
                        HT.HTML(h3_6),HT.HTML(tb6),
                        HT.HTML(h3_7),HT.HTML(tb7),
                        HT.HTML(h3_8),HT.HTML(tb8),
                        HT.HTML(h3_9),HT.HTML(tb9),
                        HT.HTML(h3_10),HT.HTML(tb10),
                        HT.HTML(h3_11),HT.HTML(tb11),
                        HT.HTML(h3_12),HT.HTML(tb12),
                        HT.HTML(h3_13),HT.HTML(tb13),
                        HT.HTML(h3_14),HT.HTML(tb14),
                        HT.HTML(h3_15),HT.HTML(tb15),
                        HT.HTML(h3_16),HT.HTML(tb16),
                        HT.HTML(h3_17),HT.HTML(tb17),
                        HT.HTML(h3_18),HT.HTML(tb18),
                        HT.HTML(h3_19),HT.HTML(tb19),
                        HT.HTML(h3_20),HT.HTML(tb20)
                        ))

outputFile = open("../FinalResults/twoFeatures.html","w")
outputFile.write(fullFl)
outputFile.close()

# %%
def getHTMLTabForFtr(ftr):
    d = drs.ovrallShrCntsByFtr(drs.gidAidMapFl,drs.aidFeatureMapFl,ftr,drs.imgJobMap,1,100)
    head3 = HT.h3("Data-Frame by " + ftr)
    df1,tb1 = genHTMLTableFiles(d)
    
    img = HT.img(src=str("images/" + ftr + "_expt2.png"))
    df1.plot(kind='bar')
    plt.savefig(str("../FinalResults/images/" + ftr + "_expt2.png"),bbox_inches='tight')

    df1.reset_index(inplace=True)
    df1.columns = [ftr,'Share Proportion']
    
    a,b,c = drs.genObjsForConsistency(drs.gidAidMapFl,drs.aidFeatureMapFl,ftr,drs.imgJobMap)    
    consistency = drs.getConsistencyDict(a,b,c)
    
    df2 = pd.DataFrame(drs.genVarStddevShrPropAcrsAlbms(consistency)).transpose()
    df2.reset_index(inplace=True)
    df2.columns = [ftr,'mean','standard_deviation','variance']
    
    df = pd.merge(df1,df2,left_on=ftr,right_on=ftr,how='left')
    
    return df,head3,df.to_html(bold_rows = False,index=False),img

# %%
df1,h3_1,tb1,img1 = getHTMLTabForFtr("SPECIES")
df2,h3_2,tb2,img2 = getHTMLTabForFtr("AGE")
df3,h3_3,tb3,img3 = getHTMLTabForFtr("VIEW_POINT")
df4,h3_4,tb4,img4 = getHTMLTabForFtr("QUALITY")
df5,h3_5,tb5,img5 = getHTMLTabForFtr("EXEMPLAR_FLAG")
df6,h3_6,tb6,img6 = getHTMLTabForFtr("CONTRIBUTOR")
fullFl = HT.html(HT.body(HT.HTML(h3_1),HT.HTML(tb1), HT.html(img1),
                        HT.HTML(h3_2),HT.HTML(tb2), HT.html(img2),
                        HT.HTML(h3_3),HT.HTML(tb3), HT.html(img3),
                        HT.HTML(h3_4),HT.HTML(tb4), HT.html(img4),
                        HT.HTML(h3_5),HT.HTML(tb5), HT.html(img5),
                        HT.HTML(h3_6),HT.HTML(tb6), HT.html(img6)
                         ))

outputFile = open("../FinalResults/oneFeature.html","w")
outputFile.write(fullFl)
outputFile.close()

plt.close('all')
# Out:
# /Users/sreejithmenon/anaconda/lib/python3.5/site-packages/matplotlib/pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
df = pd.DataFrame(drs.genAlbmFtrs(drs.gidAidMapFl,drs.aidFeatureMapFl,drs.imgJobMap,['SPECIES','AGE','SEX'])).transpose()
fullFl= HT.html(HT.body(HT.HTML(df.to_html(bold_rows = False))))

df.to_csv("../FinalResults/albumProperties.csv",index=False)
outputFile = open("../FinalResults/albumProperties.html","w")
outputFile.write(fullFl)
outputFile.close()

# %%
# DO NOT RUN AGAIN WITHOUT TAKING BACKUP OF THE HTML FILE
imgAlbmShrs,consistency = drs.getShrPropImgsAcrossAlbms(drs.imgJobMap,1,100,"../FinalResults/shareRateSameImgsAcrossAlbums.json")
df = pd.DataFrame(imgAlbmShrs,index=["Share Proportion"]).transpose()
gidShrVarStdDevDict = drs.genVarStddevShrPropAcrsAlbms(consistency)
df2 = pd.DataFrame(gidShrVarStdDevDict).transpose()
df2.reset_index(inplace=True)
df2.columns = ['GID','Standard Deviation','Variance']

subindex = df.groupby(level=0).head(1).index
subindex2 = df2.groupby(level=0).head(1)['Standard Deviation']
subindex3 = df2.groupby(level=0).head(1)['Variance']
df.loc[subindex, 'Standard Deviation'] = subindex2.get_values()
df.loc[subindex, 'Variance'] = subindex3.get_values()

df.to_csv("../FinalResults/shareRateSameImgsAcrossAlbums.csv")

df.loc[subindex, 'URL'] = '<img src = "https://socialmediabias.blob.core.windows.net/wildlifephotos/All_Zebra_Count_Images/' + subindex.get_level_values(0) + '.jpeg" width = "350">'
df = df.fillna("")

fullFl= HT.html(HT.body(HT.HTML(df.to_html(bold_rows = False))))
outputFile = open("../FinalResults/shareRateSameImgsAcrossAlbums.html","w")
outputFile.write(fullFl)
outputFile.close()

df = pd.DataFrame(sorted(gidShrVarStdDevDict.items(),key = lambda x : x[1]['standard_deviation'],reverse=True),columns=['GID','Stats'])
df.to_csv("../FinalResults/ImgsStdDevDesc.csv",index=False)

# %%
summaryPosCnt = drs.getPosShrProptn(drs.imgJobMap,1,100)

df = pd.DataFrame(summaryPosCnt).transpose()
cols = ['share','not_share','total','proportion']
df = df[cols]
imgTg = HT.img(src="images/PositionBias.png")
df.plot()
plt.savefig("../FinalResults/PositionBias.png",bbox_inches='tight')

fullFl= HT.html(HT.body(HT.HTML(df.to_html(bold_rows = False))),HT.HTML(imgTg))
outputFile = open("../FinalResults/PositionBias.html","w")
outputFile.write(fullFl)
outputFile.close()

# %%
df[['share','not_share','proportion']].plot()
plt.show()

# %%
# Overall share statistics ranked by shared proportion of images along with features and tags
df = pd.DataFrame.from_csv("../FinalResults/resultsFeaturesComb_expt2.csv")
df.reset_index(inplace=True)

df = df[[ 'GID', 'AID','Album', 'AGE',
       'EXEMPLAR_FLAG', 'INDIVIDUAL_NAME', 'NID', 'QUALITY', 'SEX', 'SPECIES',
       'VIEW_POINT']]
df = df.groupby('GID').agg(','.join)
df.reset_index(inplace=True)
df.GID = df.GID.astype(str)

dfRes = pd.DataFrame.from_csv("../FinalResults/resultsExpt2RankList_Tags.csv")
dfRes.reset_index(inplace=True)
dfRes.GID = dfRes.GID.astype(str)
dfRes['URL'] = '<img src = "https://socialmediabias.blob.core.windows.net/wildlifephotos/All_Zebra_Count_Images/' + dfRes['GID'] + '.jpeg" width = "350">'

dfSummary = pd.merge(df,dfRes,left_on ='GID',right_on='GID')
dfSummary.sort_values(by='Proportion',ascending=False,inplace=True)
dfSummary = dfSummary[['GID','Album','AGE','INDIVIDUAL_NAME','QUALITY','SEX','SPECIES','VIEW_POINT','tags','Shares','Not Shares','Total','Proportion','URL']]
dfSummary.to_csv("../FinalResults/ImgShrRnkListWithTags.csv",index=False)

fullFl= HT.html(HT.body(HT.HTML(dfSummary.to_html(bold_rows = False,index=False))))
outputFile = open("../FinalResults/ImgShrRnkListWithTags.html","w")
outputFile.write(fullFl)
outputFile.close()

# %%
imgAlbmShrs,consistency = drs.getShrPropImgsAcrossAlbms(drs.imgJobMap,1,100,"../FinalResults/shareRateSameImgsAcrossAlbums.json")
drs.genVarStddevShrPropAcrsAlbms(consistency)
# Out:
# {'10': {'standard_deviation': 0.0, 'variance': 0.0},
#  '1061': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '1102': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '1300': {'standard_deviation': 28.284271247461902, 'variance': 800.0},
#  '1301': {'standard_deviation': 20.427529234278037,
#   'variance': 417.28395061728384},
#  '1307': {'standard_deviation': 8.838834764831844, 'variance': 78.125},
#  '1315': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '1329': {'standard_deviation': 0.0, 'variance': 0.0},
#  '1332': {'standard_deviation': 0.0, 'variance': 0.0},
#  '1338': {'standard_deviation': 2.357022603955155,
#   'variance': 5.555555555555539},
#  '141': {'standard_deviation': 0.0, 'variance': 0.0},
#  '1753': {'standard_deviation': 32.99831645537222,
#   'variance': 1088.8888888888891},
#  '1781': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '1793': {'standard_deviation': 7.856742013183858,
#   'variance': 61.72839506172835},
#  '1869': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '1920': {'standard_deviation': 15.90990257669732, 'variance': 253.125},
#  '193': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '195': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '1957': {'standard_deviation': 1.7677669529663689, 'variance': 3.125},
#  '1968': {'standard_deviation': 27.498597046143512,
#   'variance': 756.1728395061727},
#  '2032': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '226': {'standard_deviation': 42.42640687119285, 'variance': 1800.0},
#  '242': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '2451': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '2458': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '282': {'standard_deviation': 35.35533905932738, 'variance': 1250.0},
#  '3076': {'standard_deviation': 0.0, 'variance': 0.0},
#  '3078': {'standard_deviation': 0.0, 'variance': 0.0},
#  '3084': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '3106': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '3115': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '3116': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '3117': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '312': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '3122': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '3131': {'standard_deviation': 5.773502691896257,
#   'variance': 33.33333333333333},
#  '316': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '3162': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '3204': {'standard_deviation': 20.427529234278037,
#   'variance': 417.28395061728384},
#  '3219': {'standard_deviation': 0.0, 'variance': 0.0},
#  '3226': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '3240': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '3262': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '3312': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '3327': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '3328': {'standard_deviation': 0.0, 'variance': 0.0},
#  '3348': {'standard_deviation': 0.0, 'variance': 0.0},
#  '3355': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '3373': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '3375': {'standard_deviation': 20.0, 'variance': 400.0},
#  '34': {'standard_deviation': 23.09401076758503,
#   'variance': 533.3333333333333},
#  '3404': {'standard_deviation': 10.0, 'variance': 100.0},
#  '3407': {'standard_deviation': 0.0, 'variance': 0.0},
#  '3410': {'standard_deviation': 0.0, 'variance': 0.0},
#  '3411': {'standard_deviation': 0.0, 'variance': 0.0},
#  '3416': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '3417': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '3434': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '3438': {'standard_deviation': 0.0, 'variance': 0.0},
#  '3455': {'standard_deviation': 28.284271247461902, 'variance': 800.0},
#  '346': {'standard_deviation': 0.0, 'variance': 0.0},
#  '3462': {'standard_deviation': 21.213203435596427, 'variance': 450.0},
#  '3466': {'standard_deviation': 11.547005383792515,
#   'variance': 133.33333333333331},
#  '3473': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '3485': {'standard_deviation': 0.0, 'variance': 0.0},
#  '351': {'standard_deviation': 5.773502691896257,
#   'variance': 33.33333333333333},
#  '352': {'standard_deviation': 17.00883333808153,
#   'variance': 289.30041152263374},
#  '353': {'standard_deviation': 17.320508075688775, 'variance': 300.0},
#  '354': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '357': {'standard_deviation': 20.0, 'variance': 400.0},
#  '359': {'standard_deviation': 5.499719409228703,
#   'variance': 30.24691358024692},
#  '360': {'standard_deviation': 15.642613529224947,
#   'variance': 244.69135802469134},
#  '362': {'standard_deviation': 30.068508881177472,
#   'variance': 904.1152263374486},
#  '363': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '369': {'standard_deviation': 21.213203435596427, 'variance': 450.0},
#  '371': {'standard_deviation': 5.010277503136549,
#   'variance': 25.102880658436213},
#  '372': {'standard_deviation': 17.320508075688775, 'variance': 300.0},
#  '373': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '374': {'standard_deviation': 28.284271247461902, 'variance': 800.0},
#  '376': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '379': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '382': {'standard_deviation': 21.213203435596427, 'variance': 450.0},
#  '386': {'standard_deviation': 5.773502691896257,
#   'variance': 33.33333333333333},
#  '388': {'standard_deviation': 25.16611478423583,
#   'variance': 633.3333333333333},
#  '392': {'standard_deviation': 28.284271247461902, 'variance': 800.0},
#  '393': {'standard_deviation': 21.213203435596427, 'variance': 450.0},
#  '394': {'standard_deviation': 20.816659994661325,
#   'variance': 433.3333333333333},
#  '395': {'standard_deviation': 28.284271247461902, 'variance': 800.0},
#  '398': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '399': {'standard_deviation': 16.32993161855452,
#   'variance': 266.6666666666667},
#  '400': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '402': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '403': {'standard_deviation': 10.0, 'variance': 100.0},
#  '405': {'standard_deviation': 35.35533905932738, 'variance': 1250.0},
#  '478': {'standard_deviation': 30.0, 'variance': 900.0},
#  '479': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '481': {'standard_deviation': 28.284271247461902, 'variance': 800.0},
#  '485': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '4870': {'standard_deviation': 0.0, 'variance': 0.0},
#  '4872': {'standard_deviation': 0.0, 'variance': 0.0},
#  '4876': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '4877': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '4887': {'standard_deviation': 28.284271247461902, 'variance': 800.0},
#  '4893': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '4895': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '4897': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '4899': {'standard_deviation': 21.213203435596427, 'variance': 450.0},
#  '4900': {'standard_deviation': 0.0, 'variance': 0.0},
#  '4901': {'standard_deviation': 0.0, 'variance': 0.0},
#  '4905': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '4908': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '4909': {'standard_deviation': 20.0, 'variance': 400.0},
#  '4913': {'standard_deviation': 11.547005383792516,
#   'variance': 133.33333333333334},
#  '4914': {'standard_deviation': 11.547005383792515,
#   'variance': 133.33333333333331},
#  '4922': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '4924': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '4925': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '4926': {'standard_deviation': 26.457513110645905, 'variance': 700.0},
#  '4928': {'standard_deviation': 28.284271247461902, 'variance': 800.0},
#  '4931': {'standard_deviation': 0.0, 'variance': 0.0},
#  '4932': {'standard_deviation': 21.213203435596427, 'variance': 450.0},
#  '4940': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '496': {'standard_deviation': 16.923940235253127,
#   'variance': 286.4197530864197},
#  '4968': {'standard_deviation': 21.213203435596427, 'variance': 450.0},
#  '497': {'standard_deviation': 11.547005383792516,
#   'variance': 133.33333333333334},
#  '4970': {'standard_deviation': 0.0, 'variance': 0.0},
#  '4977': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '4979': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '4982': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '4985': {'standard_deviation': 10.0, 'variance': 100.0},
#  '4986': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '4993': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '4996': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '5002': {'standard_deviation': 10.0, 'variance': 100.0},
#  '5003': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '5005': {'standard_deviation': 0.0, 'variance': 0.0},
#  '5009': {'standard_deviation': 20.816659994661325,
#   'variance': 433.3333333333333},
#  '5010': {'standard_deviation': 35.35533905932738, 'variance': 1250.0},
#  '5014': {'standard_deviation': 11.547005383792515,
#   'variance': 133.33333333333331},
#  '5019': {'standard_deviation': 0.0, 'variance': 0.0},
#  '5021': {'standard_deviation': 15.275252316519467,
#   'variance': 233.33333333333334},
#  '503': {'standard_deviation': 5.773502691896257,
#   'variance': 33.33333333333333},
#  '505': {'standard_deviation': 21.213203435596427, 'variance': 450.0},
#  '516': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '5174': {'standard_deviation': 0.0, 'variance': 0.0},
#  '5178': {'standard_deviation': 21.213203435596427, 'variance': 450.0},
#  '5208': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '5220': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '5226': {'standard_deviation': 21.213203435596427, 'variance': 450.0},
#  '5238': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '531': {'standard_deviation': 10.999438818457406,
#   'variance': 120.98765432098767},
#  '533': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '536': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '5369': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '54': {'standard_deviation': 10.0, 'variance': 100.0},
#  '5450': {'standard_deviation': 0.0, 'variance': 0.0},
#  '550': {'standard_deviation': 21.213203435596427, 'variance': 450.0},
#  '5500': {'standard_deviation': 21.213203435596427, 'variance': 450.0},
#  '5552': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '556': {'standard_deviation': 21.213203435596427, 'variance': 450.0},
#  '56': {'standard_deviation': 28.284271247461902, 'variance': 800.0},
#  '564': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '5657': {'standard_deviation': 20.0, 'variance': 400.0},
#  '5666': {'standard_deviation': 28.284271247461902, 'variance': 800.0},
#  '5668': {'standard_deviation': 21.213203435596427, 'variance': 450.0},
#  '5674': {'standard_deviation': 28.284271247461902, 'variance': 800.0},
#  '5677': {'standard_deviation': 11.547005383792515,
#   'variance': 133.33333333333331},
#  '5692': {'standard_deviation': 0.0, 'variance': 0.0},
#  '5704': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '5708': {'standard_deviation': 0.0, 'variance': 0.0},
#  '5713': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '5717': {'standard_deviation': 0.0, 'variance': 0.0},
#  '5734': {'standard_deviation': 0.0, 'variance': 0.0},
#  '5737': {'standard_deviation': 10.0, 'variance': 100.0},
#  '5739': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '5753': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '5768': {'standard_deviation': 35.35533905932738, 'variance': 1250.0},
#  '583': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '585': {'standard_deviation': 42.42640687119285, 'variance': 1800.0},
#  '589': {'standard_deviation': 42.42640687119285, 'variance': 1800.0},
#  '611': {'standard_deviation': 9.42809041582063,
#   'variance': 88.88888888888883},
#  '619': {'standard_deviation': 0.0, 'variance': 0.0},
#  '628': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '631': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '632': {'standard_deviation': 28.284271247461902, 'variance': 800.0},
#  '635': {'standard_deviation': 3.1426968052735433,
#   'variance': 9.876543209876536},
#  '642': {'standard_deviation': 3.1426968052735433,
#   'variance': 9.876543209876536},
#  '6597': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '705': {'standard_deviation': 17.82401394891254,
#   'variance': 317.69547325102883},
#  '706': {'standard_deviation': 28.284271247461902, 'variance': 800.0},
#  '710': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '723': {'standard_deviation': 18.070506630322882,
#   'variance': 326.54320987654324},
#  '734': {'standard_deviation': 5.091750772173155,
#   'variance': 25.925925925925924},
#  '7532': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '76': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '7744': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '7745': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '7753': {'standard_deviation': 28.284271247461902, 'variance': 800.0},
#  '7754': {'standard_deviation': 20.42752923427804,
#   'variance': 417.28395061728395},
#  '7757': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '7759': {'standard_deviation': 1.5713484026367717,
#   'variance': 2.469135802469134},
#  '7763': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '7770': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '7771': {'standard_deviation': 3.9283710065919317,
#   'variance': 15.432098765432107},
#  '7772': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '7773': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '7776': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '7777': {'standard_deviation': 4.714045207910321,
#   'variance': 22.222222222222253},
#  '7778': {'standard_deviation': 0.0, 'variance': 0.0},
#  '7796': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '7797': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '7861': {'standard_deviation': 42.42640687119285, 'variance': 1800.0},
#  '7933': {'standard_deviation': 10.0, 'variance': 100.0},
#  '7945': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '7977': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '8003': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '83': {'standard_deviation': 10.999438818457406,
#   'variance': 120.98765432098767},
#  '8315': {'standard_deviation': 15.275252316519467,
#   'variance': 233.33333333333334},
#  '8316': {'standard_deviation': 20.816659994661325,
#   'variance': 433.3333333333333},
#  '8317': {'standard_deviation': 13.440923934536338,
#   'variance': 180.6584362139918},
#  '8318': {'standard_deviation': 14.469796128487781, 'variance': 209.375},
#  '8320': {'standard_deviation': 49.49747468305833, 'variance': 2450.0},
#  '8321': {'standard_deviation': 28.284271247461902, 'variance': 800.0},
#  '8322': {'standard_deviation': 14.719601443879744,
#   'variance': 216.66666666666666},
#  '8323': {'standard_deviation': 0.0, 'variance': 0.0},
#  '8324': {'standard_deviation': 0.0, 'variance': 0.0},
#  '8325': {'standard_deviation': 9.574271077563381,
#   'variance': 91.66666666666667},
#  '8326': {'standard_deviation': 14.667087536048983,
#   'variance': 215.12345679012344},
#  '8327': {'standard_deviation': 18.929694486000912,
#   'variance': 358.3333333333333},
#  '8328': {'standard_deviation': 14.832396974191326, 'variance': 220.0},
#  '8329': {'standard_deviation': 20.0, 'variance': 400.0},
#  '8330': {'standard_deviation': 11.547005383792516,
#   'variance': 133.33333333333334},
#  '8331': {'standard_deviation': 20.816659994661325,
#   'variance': 433.3333333333333},
#  '8332': {'standard_deviation': 5.0, 'variance': 25.0},
#  '8334': {'standard_deviation': 23.596400646217003,
#   'variance': 556.7901234567902},
#  '8335': {'standard_deviation': 11.2765461834358,
#   'variance': 127.16049382716051},
#  '8336': {'standard_deviation': 26.457513110645905, 'variance': 700.0},
#  '8337': {'standard_deviation': 19.407902170679517,
#   'variance': 376.66666666666663},
#  '8338': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '8339': {'standard_deviation': 19.531550923607718,
#   'variance': 381.48148148148147},
#  '8340': {'standard_deviation': 0.0, 'variance': 0.0},
#  '8341': {'standard_deviation': 15.0, 'variance': 225.0},
#  '8342': {'standard_deviation': 8.94427190999916, 'variance': 80.0},
#  '8343': {'standard_deviation': 19.531550923607718,
#   'variance': 381.48148148148147},
#  '8345': {'standard_deviation': 11.642832797715322,
#   'variance': 135.55555555555557},
#  '8346': {'standard_deviation': 8.16496580927726,
#   'variance': 66.66666666666667},
#  '8347': {'standard_deviation': 0.641500299099584,
#   'variance': 0.41152263374485565},
#  '8348': {'standard_deviation': 6.119522830317891,
#   'variance': 37.44855967078189},
#  '8349': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '8350': {'standard_deviation': 23.874672772626646, 'variance': 570.0},
#  '8351': {'standard_deviation': 4.931631338038254,
#   'variance': 24.320987654320977},
#  '8352': {'standard_deviation': 18.257418583505537,
#   'variance': 333.3333333333333},
#  '8353': {'standard_deviation': 17.07825127659933,
#   'variance': 291.6666666666667},
#  '84': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '841': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '8566': {'standard_deviation': 21.213203435596427, 'variance': 450.0},
#  '8619': {'standard_deviation': 35.35533905932738, 'variance': 1250.0},
#  '9239': {'standard_deviation': 0.0, 'variance': 0.0},
#  '93': {'standard_deviation': 21.213203435596427, 'variance': 450.0},
#  '9386': {'standard_deviation': 0.0, 'variance': 0.0},
#  '94': {'standard_deviation': 34.64101615137755, 'variance': 1200.0},
#  '95': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '952': {'standard_deviation': 0.0, 'variance': 0.0},
#  '954': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '96': {'standard_deviation': 17.320508075688775, 'variance': 300.0},
#  '961': {'standard_deviation': 0.0, 'variance': 0.0},
#  '963': {'standard_deviation': 28.284271247461902, 'variance': 800.0},
#  '965': {'standard_deviation': 0.0, 'variance': 0.0},
#  '966': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '968': {'standard_deviation': 35.35533905932738, 'variance': 1250.0},
#  '973': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '974': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '975': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '978': {'standard_deviation': 14.142135623730951, 'variance': 200.0},
#  '979': {'standard_deviation': 7.0710678118654755, 'variance': 50.0},
#  '983': {'standard_deviation': 0.0, 'variance': 0.0},
#  '984': {'standard_deviation': 14.142135623730951, 'variance': 200.0}}
