# %%
import csv

# %%
reader = csv.reader(open("../data/consolidatedHITResultsWithInfo.csv","r"))
head = reader.__next__()

data = []
for row in reader:
    data.append(row)

# %%
# logic for creating the hyper-links
hyperLinks = []
for row in data:
    hyperLinks.append("http://pachy.cs.uic.edu:5000/api/image/src/" + str(row[0]) + "/?resize_pix_w=300")

# %%
hyperIndex = 0
for row in data:
    print("<tr>")
    print("    <td>")
    print('    <img src = "' + hyperLinks[hyperIndex] + '"alt="Unavailable"/>')
    print("    </td>")
    print("    <td><center>")
    print(row[1])
    print("    </center></td>")
    print("    <td><center>")
    print(row[2])
    print("    </center></td>")
    print("    <td><center>")
    print(row[3])
    print("    </center></td>")
    print("    <td><center>")
    print(row[4])
    print("    </center></td>")
    print("    <td><center>")
    print(row[5])
    print("    </center></td>")
    print("    <td><center>")
    print(row[6])
    print("    </center></td>")
    print("    <td><center>")
    print(row[7])
    print("    </center></td>")
    print("    <td><center>")
    print(row[8])
    print("    </center></td>")
    print("    <td><center>")
    print(row[9])
    print("    </center></td>")
    print("</tr>")

    hyperIndex += 1
# Out:
# <tr>
#     <td>
#     <img src = "http://pachy.cs.uic.edu:5000/api/image/src/926/?resize_pix_w=300"alt="Unavailable"/>
#     </td>
#     <td><center>
# 20
#     </center></td>
#     <td><center>
# 0
#     </center></td>
#     <td><center>
# 20
#     </center></td>
#     <td><center>
# 9473
#     </center></td>
#     <td><center>
# giraffe_masai
#     </center></td>
#     <td><center>
# UNKNOWN NAME
#     </center></td>
#     <td><center>
# [-1, -1]
#     </center></td>
#     <td><center>
# 0
#     </center></td>
#     <td><center>
# ok
#     </center></td>
# </tr>
# <tr>
#     <td>
#     <img src = "http://pachy.cs.uic.edu:5000/api/image/src/1712/?resize_pix_w=300"alt="Unavailable"/>
#     </td>
#     <td><center>
# 20
#     </center></td>
#     <td><center>
# 0
#     </center></td>
#     <td><center>
# 20
#     </center></td>
#     <td><center>
#
#     </center></td>
#     <td><center>
# NULL
#     </center></td>
#     <td><center>
# NULL
#     </center></td>
#     <td><center>
# ...

# %%
for h in hyperLinks:
    print(h)
