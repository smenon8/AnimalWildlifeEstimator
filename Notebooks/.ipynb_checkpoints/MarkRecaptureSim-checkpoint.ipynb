# %%
import json
from datetime import datetime
import DataStructsHelperAPI as DS
import importlib
importlib.reload(DS)

# %%
with open("../data/imgs_exif_data.json","r") as inpFl:
    jsonObj = json.load(inpFl)

# %%
imgDateDict = {gid : DS.getDateFromStr(jsonObj[gid]['datetime'],'%Y-%m-%d %H:%M:%S','%Y-%m-%d') for gid in jsonObj.keys()}

# %%
markRecapSrc = {'2015-03-01' : 'M',
               '2015-03-02' : 'R'}

filteredGid = filter(lambda x : imgDateDict[x] in markRecapSrc.keys(),imgDateDict.keys())

gidsMarkRecap = { gid : markRecapSrc[imgDateDict[gid]] for gid in filteredGid}

# %%
gidsMarkRecap
# Out:
# {'4816': 'R',
#  '628': 'M',
#  '5680': 'R',
#  '6811': 'R',
#  '1238': 'M',
#  '5446': 'M',
#  '4319': 'R',
#  '561': 'M',
#  '546': 'M',
#  '4746': 'R',
#  '1268': 'M',
#  '1321': 'M',
#  '7581': 'M',
#  '1973': 'M',
#  '2935': 'R',
#  '1337': 'M',
#  '681': 'M',
#  '518': 'M',
#  '5513': 'M',
#  '3484': 'M',
#  '1112': 'M',
#  '1176': 'M',
#  '4886': 'M',
#  '4981': 'M',
#  '431': 'M',
#  '6431': 'R',
#  '3124': 'M',
#  '2284': 'M',
#  '328': 'M',
#  '449': 'M',
#  '5081': 'R',
#  '5002': 'M',
#  '1155': 'M',
#  '6590': 'R',
#  '1753': 'M',
#  '1760': 'M',
#  '2234': 'M',
#  '7640': 'M',
#  '3079': 'M',
#  '1917': 'M',
#  '5231': 'R',
#  '2470': 'M',
#  '7410': 'M',
#  '496': 'M',
#  '4993': 'M',
#  '884': 'M',
#  '7775': 'M',
#  '6244': 'M',
#  '909': 'M',
#  '3240': 'M',
#  '739': 'M',
#  '3165': 'M',
#  '6587': 'R',
#  '5695': 'R',
#  '4985': 'M',
#  '4584': 'R',
#  '1057': 'M',
#  '7353': 'M',
#  '657': 'M',
#  '3151': 'M',
#  '4842': 'R',
#  '977': 'M',
#  '4934': 'M',
# ...

# %%
imgDateDict['1515']
# Out:
# '2015-03-01'
